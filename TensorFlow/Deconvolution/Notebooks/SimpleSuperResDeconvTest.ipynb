# %% [markdown]
# # Simple Super Image Resolution Test with the Deconvolutional Layer
#
# This notebook will document the process of taking an image dataset blurring with a convolution operation with a 2 by 2 kernel. The blurred image will be taken as an input for the Deconvolution Neural Network where the network will try to predict the unblurred image.

# %% [markdown]
# ## Import relevant libraries

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from Deconvolution.CustomLayers.DeconvDft2dLayer import DeconvDft2dLayer

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np
import os
from random import random

# %% [markdown]
# ## Defining functions for blurring images
#
# `get_imgs_from_dir(ds_path, target_size)` gets the image dataset from the specific directory
#
# `easy_two_by_two_blur(ds_path)` applies a simple blur to the images in the given path and outputs it to a folder, in the same directory, called two_by_two_blur

# %%
def get_imgs_from_dir(ds_path, color_mode='grayscale', target_size=[256, 256]):
    img_names = os.listdir(ds_path)
    imgs = []

    for img_name in img_names:
        if img_name[-4:] == '.png':
            img_path = os.path.join(ds_path, img_name)
            img = tf.keras.utils.load_img(img_path,
                                          color_mode=color_mode,
                                          target_size=target_size)
            img = tf.keras.preprocessing.image.img_to_array(img)
            imgs.append(img)
    aug_imgs = imgs

    imgs_tensor = tf.constant(aug_imgs, dtype=tf.float32)
    x_train = imgs_tensor / 255.0

    return x_train

def easy_two_by_two_blur_ds(ds_path):
    # get data that needs to be transformed
    print('Loading data')
    imgs = get_imgs_from_dir(ds_path, color_mode='rgb')
    print('Data Loaded!')
    
    
    # set up convolution kernel
    k = np.array([[0.5, 0.5],
                  [0.5, 0.5]], dtype=np.float32)
    k0 = np.zeros(k.shape, dtype=np.float32)

    kr = np.array([k, k0, k0], dtype=np.float32)
    kg = np.array([k0, k, k0], dtype=np.float32)
    kb = np.array([k0, k0, k], dtype=np.float32)

    kf = np.array([kr, kg, kb])
    kf = tf.transpose(kf, perm=[2, 3, 1, 0])

    kf = tf.constant(kf, dtype=tf.float32)
    
    
    # apply convolution operation to the images
    y = tf.nn.conv2d(imgs, kf, strides=[1, 1, 1, 1], padding='SAME')

    img_names = os.listdir(ds_path)
    base_path = ds_path + '/../two_by_two_blur/'

    if not os.path.exists(base_path):
        os.makedirs(base_path)
    
    # Save blurred images to new directory two_by_two_blur
    for i in range(y.shape[0]):
        if img_names[i][-4:] == '.png':
            img_path = base_path + img_names[i]
            tf.keras.utils.save_img(img_path, y[i])
            
    print('Blurring process complete! Check the directory')

# %% [markdown]
# ## Applying the blurring operation to the dataset

# %%
ds_path = 'SimpleSuperResDeconvTest/high_res/'

# NB! uncomment if you don't have the two_by_two_blur folder
# easy_two_by_two_blur_ds(ds_path)

# %% [markdown]
# ## Visualising input and output data
#
# Let's plot the high res and blurred images to double-check that the convolution operation did blur the image

# %%
img_name = os.listdir('SimpleSuperResDeconvTest/high_res/')[40]

img_hres = mpimg.imread('SimpleSuperResDeconvTest/high_res/' + img_name)
img_blur = mpimg.imread('SimpleSuperResDeconvTest/two_by_two_blur/' + img_name)

print(img_name)

plt.figure()

ax = plt.subplot(1, 2, 1)
plt.imshow(img_hres)
ax.set_title('High res image')
plt.axis('off')

ax = plt.subplot(1, 2, 2)
plt.imshow(img_blur)
ax.set_title('Simple blur image')
plt.axis('off')
# Out:
# 134.png
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# ## Loading datasets into notebook
#
# Now that the input and output data is read we can load both of these datasets into this notebook

# %%
print('Loading input data....')
x_train = get_imgs_from_dir('SimpleSuperResDeconvTest/two_by_two_blur/')
print('Loading output data....')
y_train = get_imgs_from_dir('SimpleSuperResDeconvTest/high_res/')
print('Data has been successfully loaded!')
# Out:
# Loading input data....
# Loading output data....
# Data has been successfully loaded!

# %% [markdown]
# ## Defining the Deep Learning Model
#
# Now that the data has been loaded into the notebook successfully, the deep learning model that will be trained on the data can be defined. We will use TensorFlow Keras functional API to define the model

# %%
inputs = keras.Input(shape=(256, 256, 1))
outputs = Deconv2D((2, 2))(inputs)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(
        loss='mean_absolute_error',
        optimizer=tf.keras.optimizers.Adam()
)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 1)]     0
#
#  deconv_dft2d_layer (DeconvD  (None, 256, 256, 1)      3
#  ft2dLayer)
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the Model

# %%
w_before = model.layers[1].w.numpy()
history = model.fit(x_train, y_train, epochs=10)
w_after = model.layers[1].w.numpy()
# Out:
# Epoch 1/10
# 22/22 [==============================] - 1s 13ms/step - loss: 0.0302
# Epoch 2/10
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0288
# Epoch 3/10
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0285
# Epoch 4/10
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0284
# Epoch 5/10
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0283
# Epoch 6/10
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0283
# Epoch 7/10
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0285
# Epoch 8/10
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0284
# Epoch 9/10
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0284
# Epoch 10/10
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0283

# %% [markdown]
# ## Plotting history and kernels
#
# Here we will plot the history of the mean absolute error with respect to the number of epochs. The kernels before and after training will also be displayed

# %%
# Reshaping kernels to their correct shapes
pad_w = tf.constant([[0, 0], [1, 0]])

w_after_ = tf.pad(w_after, pad_w, mode='CONSTANT', constant_values=1)
w_after_ = tf.reshape(w_after_, (2, 2))

w_before_ = tf.pad(w_before, pad_w, mode='CONSTANT', constant_values=1)
w_before_ = tf.reshape(w_before_, (2, 2))

plt.figure()

ax = plt.subplot(2, 2, 1)
ax.table(w_after_.numpy(), loc='center')
ax.set_title('kernel before training')
ax.axis('tight')
ax.axis('off')

ax = plt.subplot(2, 2, 2)
ax.table(w_before_.numpy(), loc='center')
ax.set_title('kernel after training')
ax.axis('tight')
ax.axis('off')

ax = plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
ax.set_title('Mean Absolute Error over epochs')
plt.xlabel('Epochs')
plt.ylabel('MAE')

plt.show()

# %% [markdown]
# ## Check if the output was predicted correctly
#
# Here we will plot the input data, output data, and what the Deconv NN predicted as the output

# %%
i = 10
x_img = x_train[i:i+2]
y_img = y_train[i:i+2]

y_pred = model(x_img)

plt.figure()

ax = plt.subplot(1, 3, 1)
plt.imshow(x_img[0], cmap='gray')
ax.set_title('Low res')
plt.axis('off')

ax = plt.subplot(1, 3, 2)
plt.imshow(y_img[0], cmap='gray')
ax.set_title('High Res')
plt.axis('off')

ax = plt.subplot(1, 3, 3)
plt.imshow(y_pred[0], cmap='gray')
ax.set_title('Predicted Output')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# ## Discussion
#
# The DNN seems to predict the desired output quite well. It minimises the Mean Absolute Error after a few epochs which is normal when you take into account that this problem it is solving is trivial. Next we will compare it to a simple CNN and see how it fairs against it

# %% [markdown]
# # Simple Convolution NN for Super Image Resolution

# %% [markdown]
# ## Define Simple CNN
#
# We'll define the cnn to have the same size kernel as the dnn. The optimizer and loss will also be kept the same

# %%
inputs = keras.Input(shape=(256, 256, 1))
outputs = layers.Conv2D(1, (2, 2), padding='same')(inputs)
model_cnn = keras.Model(inputs=inputs, outputs=outputs)

model_cnn.compile(
        loss='mean_absolute_error',
        optimizer=tf.keras.optimizers.Adam()
)

model_cnn.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 1)]     0
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 1)       5
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the CNN
#
# We will train the cnn over 10 epochs (the same amount of epochs as the dnn) and we will save the kernel before and after so that we can inspect it

# %%
w_before_cnn = model_cnn.layers[1].kernel.numpy()
history_cnn = model_cnn.fit(x_train, y_train, epochs=10)
w_after_cnn = model_cnn.layers[1].kernel.numpy()
# Out:
# Epoch 1/10
# 22/22 [==============================] - 1s 28ms/step - loss: 1.0260
# Epoch 2/10
# 22/22 [==============================] - 1s 25ms/step - loss: 0.9671
# Epoch 3/10
# 22/22 [==============================] - 1s 26ms/step - loss: 0.9087
# Epoch 4/10
# 22/22 [==============================] - 1s 25ms/step - loss: 0.8511
# Epoch 5/10
# 22/22 [==============================] - 1s 25ms/step - loss: 0.7946
# Epoch 6/10
# 22/22 [==============================] - 1s 25ms/step - loss: 0.7388
# Epoch 7/10
# 22/22 [==============================] - 1s 25ms/step - loss: 0.6845
# Epoch 8/10
# 22/22 [==============================] - 1s 25ms/step - loss: 0.6314
# Epoch 9/10
# 22/22 [==============================] - 1s 25ms/step - loss: 0.5801
# Epoch 10/10
# 22/22 [==============================] - 1s 25ms/step - loss: 0.5312

# %% [markdown]
# ## Plot CNN results
#
# We plot the CNN MAE history over the epochs and before/after kernels here

# %%
# Reshaping kernels to their correct shapes
pad_w = tf.constant([[0, 0], [1, 0]])

plt.figure()

ax = plt.subplot(2, 2, 1)
ax.table(w_after_cnn, loc='center')
ax.set_title('kernel before training')
ax.axis('tight')
ax.axis('off')

ax = plt.subplot(2, 2, 2)
ax.table(w_before_cnn, loc='center')
ax.set_title('kernel after training')
ax.axis('tight')
ax.axis('off')

ax = plt.subplot(2, 1, 2)
plt.plot(history_cnn.history['loss'])
ax.set_title('Mean Absolute Error over epochs')
plt.xlabel('Epochs')
plt.ylabel('MAE')

plt.show()

# %% [markdown]
# ## Plot discussion
#
# The MAE is being minimised well and could be minimised as it's trained more but for now we will keep it as for fairness of the test

# %%
i = 10
x_img = x_train[i:i+2]
y_img = y_train[i:i+2]

y_pred = model_cnn(x_img)
y_pred_dnn = model(x_img)

plt.figure()

ax = plt.subplot(2, 2, 1)
plt.imshow(x_img[0], cmap='gray')
ax.set_title('Low res')
plt.axis('off')

ax = plt.subplot(2, 2, 2)
plt.imshow(y_img[0], cmap='gray')
ax.set_title('High Res')
plt.axis('off')

ax = plt.subplot(2, 2, 3)
plt.imshow(y_pred[0], cmap='gray')
ax.set_title('CNN Output')
plt.axis('off')

ax = plt.subplot(2, 2, 4)
plt.imshow(y_pred_dnn[0], cmap='gray')
ax.set_title('DNN Output')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# ## Discussion CNN v DNN
#
# ### Comparison
#
# The DNN seemed to minimise a lot faster than the CNN. Based on the predicted outputs, the DNN also out performs the CNN since the output resembles the true output a lot better.
#
# ### Concerns
#
# Although the DNN did train faster, the trainable parameters in the kernel are a lot closer to zero which could be why it is able to minimise a lot sooner and better than the CNN

# %%
plt.figure()

ax = plt.subplot(2, 2, 1)
ax.table(w_after_cnn, loc='center')
ax.set_title('CNN kernel before training')
ax.axis('tight')
ax.axis('off')

ax = plt.subplot(2, 2, 2)
ax.table(w_before_cnn, loc='center')
ax.set_title('CNN kernel after training')
ax.axis('tight')
ax.axis('off')


ax = plt.subplot(2, 2, 3)
ax.table(w_after_.numpy(), loc='center')
ax.set_title('DNN kernel before training')
ax.axis('tight')
ax.axis('off')

ax = plt.subplot(2, 2, 4)
ax.table(w_before_.numpy(), loc='center')
ax.set_title('DNN kernel after training')
ax.axis('tight')
ax.axis('off')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)
